# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# sns.set_theme(color_codes=True)

# %%
# iris = sns.load_dataset('iris')
# sns.FacetGrid(iris)

# %%
tips = sns.load_dataset("tips")
sns.FacetGrid(tips)

# %%
sns.FacetGrid(data=tips, col='time', row='sex')

# %%
g = sns.FacetGrid(data=tips, col='time', row='sex')
g.map(sns.scatterplot, 'total_bill', 'tip');

# %%
g = sns.FacetGrid(tips, col="time",  row="sex")
g.map(sns.scatterplot, "total_bill", "tip")

# %%
g = sns.FacetGrid(tips, col="time",  row="sex")
g.map_dataframe(sns.scatterplot, x="total_bill", y="tip")

# %%
g = sns.FacetGrid(tips, col="time",  row="sex")
g.map(sns.histplot, "total_bill");

# %%
g = sns.FacetGrid(tips, col="time",  row="sex")
g.map_dataframe(sns.histplot, x="total_bill");

# %%
g = sns.FacetGrid(tips, col='time', row='sex')
g.map_dataframe(sns.histplot, x='total_bill', binwidth=2, binrange=(0, 60));

# %%
g = sns.FacetGrid(data=tips, col='time', hue='sex')
g.map_dataframe(sns.scatterplot, x='total_bill', y='tip')
g.add_legend();

# %%
g = sns.FacetGrid(tips, col='time')
g.map_dataframe(sns.scatterplot, x='total_bill', y='tip', hue='sex')
g.add_legend()

# %%
g = sns.FacetGrid(tips, col='time')
g.map_dataframe(sns.scatterplot, x='total_bill', y='tip', hue='sex', hue_order=['Female', 'Male'])
g.add_legend()

# %%
g = sns.FacetGrid(tips, col='day', height=3.5, aspect=.5)
g.map_dataframe(sns.histplot, x='total_bill')

# %%
g = sns.FacetGrid(tips, col="size", height=2.5, col_wrap=3)
g.map(sns.histplot, "total_bill");

# %%
g = sns.FacetGrid(tips, col='time')
g.map_dataframe(sns.scatterplot, x='total_bill', y='tip')
g.refline(y=tips.tip.mean())

# %%
g = sns.FacetGrid(tips, col='time')
g.map_dataframe(sns.scatterplot, x='total_bill', y='tip')
g.refline(x=4, y=5)

# %% [markdown]
# # * pass custom function

# %%
import matplotlib.pyplot as plt
def annotate(data, **kws):
    n = len(data)
    ax = plt.gca()
    ax.text(.1, .6, f"N = {n}", transform=ax.transAxes)

g = sns.FacetGrid(tips, col="time")
g.map_dataframe(sns.scatterplot, x="total_bill", y="tip")
g.map_dataframe(annotate)

# %%
g = sns.FacetGrid(tips, col="sex", row="time", margin_titles=True)
g.map_dataframe(sns.scatterplot, x="total_bill", y="tip")
g.set_axis_labels("Total bill ($)", "Tip ($)")
g.set_titles(col_template="{col_name} patrons", row_template="{row_name}")
g.set(xlim=(0, 60), ylim=(0, 12), xticks=[10, 30, 50], yticks=[2, 6, 10])
g.tight_layout()
g.savefig("facet_plot.png")
# Out:
# [[<AxesSubplot:title={'center':'Male patrons'}, ylabel='Tip ($)'>
#   <AxesSubplot:title={'center':'Female patrons'}>]
#  [<AxesSubplot:xlabel='Total bill ($)', ylabel='Tip ($)'>
#   <AxesSubplot:xlabel='Total bill ($)'>]]

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [31], in <cell line: 1>()
# ----> 1 g.ax
#
# File ~\miniconda3\envs\adp\lib\site-packages\seaborn\axisgrid.py:1037, in FacetGrid.ax(self)
#    1033 else:
#    1034     err = (
#    1035         "Use the `.axes` attribute when facet variables are assigned."
#    1036     )
# -> 1037     raise AttributeError(err)
#
# AttributeError: Use the `.axes` attribute when facet variables are assigned.

# %%
g = sns.FacetGrid(tips, col="sex", row="time", margin_titles=True, despine=False)
g.map_dataframe(sns.scatterplot, x="total_bill", y="tip")
g.figure.subplots_adjust(wspace=0, hspace=0)
for (row_val, col_val), ax in g.axes_dict.items():
    if row_val == "Lunch" and col_val == "Female":
        ax.set_facecolor(".95")
    else:
        ax.set_facecolor((0, 0, 0, 0))

# %%
g = sns.FacetGrid(tips, col="sex", row="time", margin_titles=True, despine=True)
g.map_dataframe(sns.scatterplot, x="total_bill", y="tip")
g.figure.subplots_adjust(wspace=0, hspace=0)
for (row_val, col_val), ax in g.axes_dict.items():
    if row_val == "Lunch" and col_val == "Female":
        ax.set_facecolor(".95")
    else:
        ax.set_facecolor((0, 0, 0, 0))
