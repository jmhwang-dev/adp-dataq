# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
from sklearn.datasets import fetch_california_housing

# %%
california_housing = fetch_california_housing(as_frame=True)

# %%
housing = california_housing.frame.copy()

# %%
housing.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseVal
# 0    -122.23        4.526
# 1    -122.22        3.585
# 2    -122.24        3.521
# 3    -122.25        3.413
# 4    -122.25        3.422

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   MedInc       20640 non-null  float64
#  1   HouseAge     20640 non-null  float64
#  2   AveRooms     20640 non-null  float64
#  3   AveBedrms    20640 non-null  float64
#  4   Population   20640 non-null  float64
#  5   AveOccup     20640 non-null  float64
#  6   Latitude     20640 non-null  float64
#  7   Longitude    20640 non-null  float64
#  8   MedHouseVal  20640 non-null  float64
# dtypes: float64(9)
# memory usage: 1.4 MB

# %%
housing.isnull().sum()
# Out:
# MedInc         0
# HouseAge       0
# AveRooms       0
# AveBedrms      0
# Population     0
# AveOccup       0
# Latitude       0
# Longitude      0
# MedHouseVal    0
# dtype: int64

# %%
housing
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  MedHouseVal
# ...

# %%
housing.hist(bins=50, figsize=(20, 15));

# %%
sns.displot(kind='hist', data=housing, x='MedInc', binwidth=1);

# %%
# sns.scatterplot(data=housing, x='Longitude', y='Latitude', alpha=.1,)
sns.scatterplot(data=housing, x='Longitude', y='Latitude', hue='MedHouseVal', )


# sns.relplot(data=housing, x='Longitude', y='Latitude', kind='scatter', alpha=0.1, size='MedHouseVal')
# Out:
# <AxesSubplot:xlabel='Longitude', ylabel='Latitude'>

# %%
pd.get_dummies(iris.species)
# Out:
#      setosa  versicolor  virginica
# 0         1           0          0
# 1         1           0          0
# 2         1           0          0
# 3         1           0          0
# 4         1           0          0
# ..      ...         ...        ...
# 145       0           0          1
# 146       0           0          1
# 147       0           0          1
# 148       0           0          1
# 149       0           0          1
#
# [150 rows x 3 columns]

# %%
sns.heatmap(housing.corr(), vmin=-1, vmax=1)
# Out:
# <AxesSubplot:>

# %%
sns.displot(data=housing, x='Longitude', y='Latitude', kind='hist', binwidth=0.01)
# sns.scatterplot(data=housing, x='Longitude', y='Latitude', alpha=0.1)
# Out:
# <AxesSubplot:xlabel='Longitude', ylabel='Latitude'>

# %%
housing.MedInc.quantile??

# %%
housing.MedInc.quantile([.25, .5, .75])
# Out:
# 0.25    2.56340
# 0.50    3.53480
# 0.75    4.74325
# Name: MedInc, dtype: float64

# %%
quant = housing.MedInc.quantile([.25, .5, .75]).to_list()

# %%
quant
# Out:
# [2.5633999999999997, 3.5347999999999997, 4.74325]

# %%
pd.cut(housing.MedInc, quant)
# Out:
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4        (3.535, 4.743]
#               ...
# 20635               NaN
# 20636               NaN
# 20637               NaN
# 20638               NaN
# 20639               NaN
# Name: MedInc, Length: 20640, dtype: category
# Categories (2, interval[float64, right]): [(2.563, 3.535] < (3.535, 4.743]]

# %%
sns.catplot(data=housing, x='MedInc', kind='box', height=2, aspect=2)

# %%
housing.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude   MedHouseVal
# count  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704      2.068558
# std       10.386050      2.135952      2.003532      1.153956
# ...

# %%
iris = sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.boxplot();

# %%
iris.plot.kde();

# %%
sns.displot(data=iris, kind='kde')

# %%
import uuid

# %%
iris['id'] = [uuid.uuid1() for _ in range(len(iris))]

# %%
iris_melted = iris.melt(id_vars='id', value_vars=iris.drop('species', axis=1).columns)
iris_melted
# Out:
#                                        id      variable  value
# 0    f7e4e678-ea27-11ec-b861-22ad71bb1791  sepal_length    5.1
# 1    f7e4e772-ea27-11ec-b861-22ad71bb1791  sepal_length    4.9
# 2    f7e4e7a4-ea27-11ec-b861-22ad71bb1791  sepal_length    4.7
# 3    f7e4e7cc-ea27-11ec-b861-22ad71bb1791  sepal_length    4.6
# 4    f7e4e7f4-ea27-11ec-b861-22ad71bb1791  sepal_length    5.0
# ..                                    ...           ...    ...
# 595  f7e4fe10-ea27-11ec-b861-22ad71bb1791   petal_width    2.3
# 596  f7e4fe38-ea27-11ec-b861-22ad71bb1791   petal_width    1.9
# 597  f7e4fe6a-ea27-11ec-b861-22ad71bb1791   petal_width    2.0
# 598  f7e4fe88-ea27-11ec-b861-22ad71bb1791   petal_width    2.3
# 599  f7e4feba-ea27-11ec-b861-22ad71bb1791   petal_width    1.8
#
# [600 rows x 3 columns]

# %%
tips = sns.load_dataset('tips')

# %%
smoker_yes = tips[tips.smoker=='Yes']
smoker_yes
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 56        38.01  3.00    Male    Yes  Sat  Dinner     4
# 58        11.24  1.76    Male    Yes  Sat  Dinner     2
# 60        20.29  3.21    Male    Yes  Sat  Dinner     2
# 61        13.81  2.00    Male    Yes  Sat  Dinner     2
# 62        11.02  1.98    Male    Yes  Sat  Dinner     2
# ..          ...   ...     ...    ...  ...     ...   ...
# 234       15.53  3.00    Male    Yes  Sat  Dinner     2
# 236       12.60  1.00    Male    Yes  Sat  Dinner     2
# 237       32.83  1.17    Male    Yes  Sat  Dinner     2
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2
# 241       22.67  2.00    Male    Yes  Sat  Dinner     2
#
# [93 rows x 7 columns]

# %%
sns.displot(smoker_yes, x='tip', col='sex')

# %%
tips.query("`smoker`=Yes")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [180], in <module>
# ----> 1 tips.query("`smoker`=Yes")
#
# File ~/miniconda3/envs/adp/lib/python3.8/site-packages/pandas/core/frame.py:4111, in DataFrame.query(self, expr, inplace, **kwargs)
#    4109 kwargs["level"] = kwargs.pop("level", 0) + 1
#    4110 kwargs["target"] = None
# -> 4111 res = self.eval(expr, **kwargs)
#    4113 try:
#    4114     result = self.loc[res]
#
# File ~/miniconda3/envs/adp/lib/python3.8/site-packages/pandas/core/frame.py:4240, in DataFrame.eval(self, expr, inplace, **kwargs)
#    4237     kwargs["target"] = self
#    4238 kwargs["resolvers"] = tuple(kwargs.get("resolvers", ())) + resolvers
# -> 4240 return _eval(expr, inplace=inplace, **kwargs)
#
# ...

# %%
g = sns.FacetGrid(iris_melted, col='variable', col_wrap=2)
# g.map_dataframe(sns.histplot, x='value', );
g.map_dataframe(sns.kdeplot, x='value');

# %%
iris.plot.line()
# Out:
# <AxesSubplot:>

# %%
iris.hist();

# %%
# sns.histplot(data=iris.drop('species', axis=1));
# sns.kdeplot(data=iris.drop('species', axis=1), fill=False);

# %%
sns.relplot(data=iris.drop('species', axis=1), kind='line');

# %%
sns.displot(data=iris, x='sepal_width', col='species')

# %%
housing.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude   MedHouseVal
# count  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704      2.068558
# std       10.386050      2.135952      2.003532      1.153956
# ...

# %%
np.ceil(housing.MedInc / 1.5)
# Out:
# 0        6.0
# 1        6.0
# 2        5.0
# 3        4.0
# 4        3.0
#         ...
# 20635    2.0
# 20636    2.0
# 20637    2.0
# 20638    2.0
# 20639    2.0
# Name: MedInc, Length: 20640, dtype: float64

# %%
housing.MedInc.where(10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [51], in <module>
# ----> 1 housing.MedInc.where(10)
#
# File ~/miniconda3/envs/adp/lib/python3.8/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/adp/lib/python3.8/site-packages/pandas/core/series.py:5569, in Series.where(self, cond, other, inplace, axis, level, errors, try_cast)
#    5556 @deprecate_nonkeyword_arguments(
#    5557     version=None, allowed_args=["self", "cond", "other"]
#    5558 )
#    (...)
#    5567     try_cast=lib.no_default,
#    5568 ):
# ...

# %%
np.ceil(housing.MedInc / 1.5)
