# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.catplot(data=tips, x='day', y='total_bill');

# %%
sns.catplot(data=tips, x='day', y='total_bill', jitter=False);

# %%
sns.catplot(data=tips, x='day', y='total_bill', hue='sex', kind='swarm');

# %%
sns.catplot(data=tips, x='size', y='total_bill');

# %%
sns.catplot(data=tips, x='smoker', y='tip')

# %%
sns.catplot(data=tips, x='smoker', y='tip', order=['No', 'Yes']);

# %%
sns.catplot(data=tips, x='day', y='total_bill', hue='time', kind='swarm');

# %%
sns.catplot(data=tips, x='total_bill', y='day', hue='time', kind='swarm');

# %%
sns.catplot(data=tips, x='day', y='total_bill', kind='box');

# %%
sns.catplot(data=tips, x='day', y='total_bill', kind='box', hue='smoker');

# %%
tips['weekend'] = tips['day'].isin(['Sat', 'Sun'])
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size  weekend
# 0         16.99  1.01  Female     No   Sun  Dinner     2     True
# 1         10.34  1.66    Male     No   Sun  Dinner     3     True
# 2         21.01  3.50    Male     No   Sun  Dinner     3     True
# 3         23.68  3.31    Male     No   Sun  Dinner     2     True
# 4         24.59  3.61  Female     No   Sun  Dinner     4     True
# ..          ...   ...     ...    ...   ...     ...   ...      ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3     True
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2     True
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2     True
# 242       17.82  1.75    Male     No   Sat  Dinner     2     True
# 243       18.78  3.00  Female     No  Thur  Dinner     2    False
#
# [244 rows x 8 columns]

# %%
sns.catplot(data=tips, x='day', y='total_bill', kind='box', hue='weekend');

# %%
sns.catplot(data=tips, x='day', y='total_bill', kind='box', hue='weekend', dodge=False);

# %%
diamonds = sns.load_dataset('diamonds')
diamonds
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %% [markdown]
# ### caution: row order ->  use `df.sort_values()`

# %%
sns.catplot(data=diamonds, x='color', y='price', kind='boxen');

# %%
sns.catplot(data=tips, x='total_bill', y='day', kind='violin', hue='sex');

# %%
sns.catplot(kind='violin', data=tips, x='total_bill', y='day', hue='sex', cut=0)

# %%
sns.catplot(kind='violin', data=tips, x='total_bill', y='day', hue='sex', bw=.15)

# %%
sns.catplot(kind='violin', data=tips, x='day', y='total_bill', hue='sex', split=True);

# %%
sns.catplot(kind='violin', data=tips, x='day', y='total_bill', hue='sex', split=True, inner='stick', palette='pastel');

# %% [markdown]
# # figure + axes ***

# %%
g = sns.catplot(x="day", y="total_bill", kind="violin", inner=None, data=tips)
sns.swarmplot(x="day", y="total_bill", color="k", size=3, data=tips, ax=g.ax);

# %%
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.catplot(kind='bar', data=titanic, x='sex', y='survived', hue='class');

# %%
sns.catplot(kind='count', data=titanic, x='deck', palette='flare');

# %%
sns.catplot(kind='count', data=titanic, y='deck', hue='class', edgecolor=".6", palette='pastel');

# %%
sns.catplot(kind='point', data=titanic, x='sex', y='survived', hue='class');

# %%
sns.catplot(kind='point', data=titanic, x='class', y='survived', hue='sex',
           palette=['g', 'y'],
           markers=["^", 'o'],
           linestyles=['-', '--']);

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.catplot(kind='box', data=iris, orient='h');

# %% [markdown]
# # adjust size

# %%
import matplotlib.pyplot as plt

# %%
f, ax = plt.subplots(figsize=(7, 3))
sns.countplot(y="deck", data=titanic, color="c");

# %% [markdown]
# # multiple relation

# %%
sns.catplot(data=tips, x='day', y='total_bill', hue='smoker', col='time',
           aspect=0.7, kind='swarm');

# %%
# fare > 0

# %%
titanic.query("fare>0")
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
g = sns.catplot(kind='box', data=titanic.query("fare>0"), x='fare', y='survived', row='class', orient='h',
           height=1.5, aspect=4)

# g.set(xscale="log")

# %%
g = sns.catplot(kind='box', data=titanic.query("fare>0"), x='fare', y='survived', 
                row='class', orient='h',
                height=1.5, aspect=4)
g.set(xscale="log")
